# %%
import pymongo
from pymongo import MongoClient
from bson import ObjectId

# %%
URL = 'mongodb+srv://admin:pedidosdecompra@cluster0.zj9tl.mongodb.net/Cluster0?'
client = MongoClient(URL)

DB = 'pedidosdecompradb'
db = client[DB]

# %%
def getPedidos():
    all_pedidos = list(collection.find())
    return all_pedidos

# %%
def getPedido(pedido_id):
    pedido_id = ObjectId(pedido_id)
    pedido = collection.find_one({'_id': ObjectId(pedido_id)})
    return pedido

# %%
def postPedido(pedido):
    res = collection.insert_one(pedido)
    return res.inserted_id

# %%
def putPedido(pedido_id, update_pedido):
    pedido_id = {"_id": ObjectId(pedido_id)}
    update_pedido = {"$set": update_pedido}
    res = collection.update_one(pedido_id, update_pedido)
    return res.modified_count

# %%
def deletePedido(pedido_id):
    pedido_id = {"_id": ObjectId(pedido_id)}
    res = collection.delete_one(pedido_id)
    return res.deleted_count

# %% [markdown]
# ---

# %%
COLLECTION = "pedidosdecompra"

# %%
collection = db[COLLECTION]

# %%
# %%time

pedidos = getPedidos()
pedidos
# Out:
# Wall time: 42 ms
# [{'_id': ObjectId('606f74aa1e87ff9190234668'),
#   'os': '12234',
#   'requisitante': 'Vitor Miranda Kurovski',
#   'email': 'kurovski@bcb.gov.br',
#   'codAutorizacao': None,
#   'dateTime': None},
#  {'_id': ObjectId('606f7a54835b08b204ec4b54'),
#   'OS': 123458,
#   'name': 'Chriszão Gatãoa',
#   'email': 'christiancf@gmail.com'}]

# %%
pedido = getPedido(ObjectId('606f7a54835b08b204ec4b5a'))
pedido

# %%
pedido = {"OS": 123458, "name": "Christian Cruvinel França", "email": "christiancf@gmail.com"}
pedido_id = postPedido(pedido)
pedido_id
# Out:
# ObjectId('606f8616e7b3d38f1801c1da')

# %%
res = deletePedido("606f8616e7b3d38f1801c1da")
res
# Out:
# 1

# %%
res = putPedido("606f7a54835b08b204ec4b54", {"name": "Chriszão Gatãoa"})
res
# Out:
# 1

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
def postMany(documents):
    res = collection.insert_many(documents)
    return res.inserted_ids

# %%
COLLECTION = "itensdisponiveis"
collection = db[COLLECTION]

# %%
# %%time

pedidos = getPedidos()
pedidos
# Out:
# Wall time: 423 ms
# [{'_id': ObjectId('6070e3301c0178a7a57c89bc'),
#   'descricao': 'Abraçadeira de Nylon até 200mm',
#   'unidade': 'unid.',
#   'fabReferencia': 'Hellerman',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89bd'),
#   'descricao': 'Abraçadeira de Nylon de +200mm a 390mm',
#   'unidade': 'unid.',
#   'fabReferencia': 'Hellerman',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89be'),
#   'descricao': 'Abraçadeira de Nylon de +390mm a 535mm',
#   'unidade': 'unid.',
#   'fabReferencia': 'Hellerman',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89bf'),
#   'descricao': 'Abraçadeira em Aço tipo Copo até 1 e 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89c0'),
#   'descricao': 'Abraçadeira em Aço tipo D até 1 e 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89c1'),
#   'descricao': 'Abraçadeira em Aço tipo Gota até 2 e 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89c2'),
#   'descricao': 'Abraçadeira em Aço tipo Rosca sem Fim até 2 e 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89c3'),
#   'descricao': 'Abraçadeira em Aço tipo U até 3"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89c4'),
#   'descricao': 'Acabamento de Registro C40',
#   'unidade': 'unid.',
#   'fabReferencia': 'Deca',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89c5'),
#   'descricao': 'Acabamento para Válvula de Descarga 4900.C.DUO',
#   'unidade': 'unid.',
#   'fabReferencia': 'Deca',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89c6'),
#   'descricao': 'Adaptador PVC - Barbará 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89c7'),
#   'descricao': 'Adaptador PVC Soldável até 40mm x 1 e 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89c8'),
#   'descricao': 'Adaptador PVC Soldável com Flange até 50mm x 1 e 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89c9'),
#   'descricao': 'Adaptador PVC Soldável com Flanges 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89ca'),
#   'descricao': 'Adaptador PVC Soldável com Flanges até 25mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89cb'),
#   'descricao': 'Adaptador PVC Soldável de +40mm x 1 e 1/2" até 75mm x 2 e 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89cc'),
#   'descricao': 'Adaptador PVC Soldável de +75mm x 2 e 1/2" até 110mm x 4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89cd'),
#   'descricao': 'Adaptador Storz Latão até 2 1/2" x 1 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89ce'),
#   'descricao': 'Adesivo Massa Durepoxi',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89cf'),
#   'descricao': 'Anel de Borracha para Vedação até 4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89d0'),
#   'descricao': 'Anel de Vedação para Esgoto 75mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89d1'),
#   'descricao': 'Anel de Vedação para Vaso Sanitário com Guia - Decanel',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89d2'),
#   'descricao': 'Anel Elástico Externo',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89d3'),
#   'descricao': 'Anilhas de Identificação para Cabos Elétricos 0,5 - 2,5mm | 0 a 9 | A a Z |',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89d4'),
#   'descricao': 'Arame Galvanizado 12 BWG',
#   'unidade': 'kg',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89d5'),
#   'descricao': 'Arejador para Torneira Deca',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89d6'),
#   'descricao': 'Arruela até 3/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89d7'),
#   'descricao': 'Barra de Conector Sindal 12 pólos 4mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89d8'),
#   'descricao': 'Barra de Tirante Roscado de Aço Inox 1/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89d9'),
#   'descricao': 'Barra de Tirante Roscado de Aço Inox 5/8"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89da'),
#   'descricao': 'Bloco de Contato 1NA ZB2-BE101',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89db'),
#   'descricao': 'Botão de Comando Duplo Liga/Desliga Iluminado 1NA+1NF 220V 22mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89dc'),
#   'descricao': 'Bucha de Redução Cobre 28mm x 22mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89dd'),
#   'descricao': 'Bucha de Redução Cobre 3/4" x 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89de'),
#   'descricao': 'Bucha de Redução Cobre 42mm x 35mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89df'),
#   'descricao': 'Bucha de Redução CPVC 22mm x 15mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89e0'),
#   'descricao': 'Bucha de Redução CPVC 28mm x 22mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89e1'),
#   'descricao': 'Bucha de Redução CPVC 54mm x 28mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89e2'),
#   'descricao': 'Bucha de Redução Ferro Galvanizado até 1" x 3/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89e3'),
#   'descricao': 'Bucha de Redução Ferro Galvanizado de +1" x 3/4" até 2" x 1 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89e4'),
#   'descricao': 'Bucha de Redução Ferro Galvanizado de +2" x 1 1/2" até 2 1/2" x 2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89e5'),
#   'descricao': 'Bucha de Redução PVC Esgoto 100mm x 75mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89e6'),
#   'descricao': 'Bucha de Redução PVC Série R 50mm x 40mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89e7'),
#   'descricao': 'Bucha de Redução PVC Soldável 110mm x 60mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89e8'),
#   'descricao': 'Bucha de Redução PVC Soldável até 50mm x 40mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89e9'),
#   'descricao': 'Bucha de Redução PVC Soldável de +50mm x 40mm até 85mm x 60mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89ea'),
#   'descricao': 'Bucha de Redução Roscável 1 1/4" x 3/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89eb'),
#   'descricao': 'Bucha para Eletroduto 3/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89ec'),
#   'descricao': 'Cabo Coaxial Rg6 75 ohms 95% de malha (Certificação Inmetro)',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89ed'),
#   'descricao': 'Cadeado 45mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89ee'),
#   'descricao': 'Caixa Sifonada 150mm x 150mm x 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89ef'),
#   'descricao': 'Campainha Pulsador Sobrepor 16A',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89f0'),
#   'descricao': 'Canaleta Lisa 60x40mm Cinza - 2 Metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89f1'),
#   'descricao': 'Canaleta Perfurada 30x50mm Cinza - 2 Metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89f2'),
#   'descricao': 'Canaleta Perfurada 50x80mm Cinza - 2 Metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89f3'),
#   'descricao': 'Canaleta PVC com Divisória 20x10 - 2 Metros',
#   'unidade': 'unid.',
#   'fabReferencia': 'Tramontina',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89f4'),
#   'descricao': 'Canaleta Sistema X sem Divisória 20x12 - 2 Metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89f5'),
#   'descricao': 'Cap CPVC Aquatherm 42mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89f6'),
#   'descricao': 'Cap PVC Roscável até 2 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89f7'),
#   'descricao': 'Cap PVC Série R de 75mm a 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89f8'),
#   'descricao': 'Cap PVC Soldável 60mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89f9'),
#   'descricao': 'Cap PVC Soldável 75mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89fa'),
#   'descricao': 'Cap PVC Soldável 85mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89fb'),
#   'descricao': 'Capacitor 15mF 250V',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89fc'),
#   'descricao': 'Chumbador CBA Jaqueta e Cone 3/8"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89fd'),
#   'descricao': 'Chumbador CBA Parabolt 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89fe'),
#   'descricao': 'Chumbador CBA Parabolt 5/8"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c89ff'),
#   'descricao': 'Chumbador CBA Parabolt até 3/8"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a00'),
#   'descricao': 'Cola Araldite Profissional 23g TEKBOND',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a01'),
#   'descricao': 'Cola CPVC Tigre 175g',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a02'),
#   'descricao': 'Cola Iberê 900g',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a03'),
#   'descricao': 'Cola Sidakur Epoxi 1Kg',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a04'),
#   'descricao': 'Condulete de Alumínio até 3/4" para Eletroduto',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a05'),
#   'descricao': 'Conector Box Reto até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a06'),
#   'descricao': 'Conector Box Reto de +1 1/2" até 2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a07'),
#   'descricao': 'Conector Box Reto de +1" até 1 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a08'),
#   'descricao': 'Conector CPVC 28mm x 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a09'),
#   'descricao': 'Conector CPVC 42mm x 1 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a0a'),
#   'descricao': 'Conector CPVC 54mm x 2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a0b'),
#   'descricao': 'Conector CPVC até 22mm x 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a0c'),
#   'descricao': 'Conector de Cobre Fêmea até 22mm x 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a0d'),
#   'descricao': 'Conector de Cobre Fêmea até 42mm x 1 1/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a0e'),
#   'descricao': 'Conector de Cobre Macho até 28mm x 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a0f'),
#   'descricao': 'Conector de Cobre Macho de +28mm x 1" até 42mm x 1 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a10'),
#   'descricao': 'Conector para Condulete Múltiplo até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a11'),
#   'descricao': 'Conector PPR Fêmea 32mm x 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a12'),
#   'descricao': 'Conector PPR Fêmea 40mm x 1 1/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a13'),
#   'descricao': 'Conector PPR Macho até 25mm x 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a14'),
#   'descricao': 'Conector Rg6 de Compressão',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a15'),
#   'descricao': 'Conector Split Bolt para Cabos até 25mm²',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a16'),
#   'descricao': 'Conjunto de Fixação para Assento Deca',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a17'),
#   'descricao': 'Cotovelo 90° Ferro Galvanizado 1" x 3/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a18'),
#   'descricao': 'Cotovelo 90° Ferro Galvanizado 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a19'),
#   'descricao': 'Cotovelo 90° Ferro Galvanizado 2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a1a'),
#   'descricao': 'Cotovelo 90° para Canaleta 20x10x2000m',
#   'unidade': 'unid.',
#   'fabReferencia': 'Tramontina',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a1b'),
#   'descricao': 'Curva 45° PVC Soldável 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a1c'),
#   'descricao': 'Curva 45° PVC Soldável 60mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a1d'),
#   'descricao': 'Curva 90 ° PVC para Eletroduto 3/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a1e'),
#   'descricao': 'Curva 90° Galvanizada para Eletroduto até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a1f'),
#   'descricao': 'Curva 90° Horizontal Branca Dutotect',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a20'),
#   'descricao': 'Curva 90° PVC Esgoto 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a21'),
#   'descricao': 'Curva 90° PVC Esgoto 40mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a22'),
#   'descricao': 'Curva 90° PVC Soldável 25mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a23'),
#   'descricao': 'Curva 90° PVC Soldável 60mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a24'),
#   'descricao': 'Curva 90° PVC Soldável de +25mm até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a25'),
#   'descricao': 'Curva Curta 90° PVC Esgoto Soldável até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a26'),
#   'descricao': 'Curva Curta 90° PVC Esgoto Soldável de +50mm até 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a27'),
#   'descricao': 'Curva Longa 90° PVC Esgoto Série R 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a28'),
#   'descricao': 'Curva Longa 90° PVC Esgoto Soldável 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a29'),
#   'descricao': 'Disco Lixa Flap 7" x 7/8"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a2a'),
#   'descricao': 'Dobradiça Gonzo com Aba até 3/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a2b'),
#   'descricao': 'Dobradiça Latão 3.5" x 3"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a2c'),
#   'descricao': 'Estanho para Solda Rolo 250g 1mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a2d'),
#   'descricao': 'Filito 20Kg',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a2e'),
#   'descricao': 'Fita Crepe 3M',
#   'unidade': 'unid.',
#   'fabReferencia': '3M',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a2f'),
#   'descricao': 'Fita de Demarcação Amarela 8mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a30'),
#   'descricao': 'Fita para Rotulador Brother 12mm x 8 metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a31'),
#   'descricao': 'Fita Perfurada para Fixação de 30 metros',
#   'unidade': 'unid.',
#   'fabReferencia': 'WALSYWA',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a32'),
#   'descricao': 'Fita Zebrada de Sinalização Preta e Amarela 200 metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a33'),
#   'descricao': 'Fusível Diazed 35A',
#   'unidade': 'unid.',
#   'fabReferencia': 'Eletromec',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a34'),
#   'descricao': 'Fusível NH 36A a 80A',
#   'unidade': 'unid.',
#   'fabReferencia': 'Eletromec',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a35'),
#   'descricao': 'Galão Massa Acrílica 3,6L',
#   'unidade': 'unid.',
#   'fabReferencia': 'SUVINIL',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a36'),
#   'descricao': 'Galão Reducola Solvente 4,6L',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a37'),
#   'descricao': 'Graute Plus Cinza 25Kg',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a38'),
#   'descricao': 'Grelha de Ferro Fundido Quadrado 40cm x 40cm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a39'),
#   'descricao': 'Grelha Inox com Caixilho 15cm x 15cm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a3a'),
#   'descricao': 'Grelha Inox Redonda 15cm x 15cm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a3b'),
#   'descricao': 'Joelho 45° PVC Esgoto até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a3c'),
#   'descricao': 'Joelho 45° PVC Esgoto de +50mm a 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a3d'),
#   'descricao': 'Joelho 45° PVC Série R até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a3e'),
#   'descricao': 'Joelho 45° PVC Série R de +50mm a 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a3f'),
#   'descricao': 'Joelho 45° PVC Série R Esgoto de +50mm a 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a40'),
#   'descricao': 'Joelho 45° PVC Soldável até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a41'),
#   'descricao': 'Joelho 45° PVC Soldável de +50mm até 60mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a42'),
#   'descricao': 'Joelho 45° PVC Soldável Esgoto até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a43'),
#   'descricao': 'Joelho 90° Cobre até 28mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a44'),
#   'descricao': 'Joelho 90° CPVC até 22mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a45'),
#   'descricao': 'Joelho 90° CPVC de +22 mm a 42mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a46'),
#   'descricao': 'Joelho 90° CPVC de +42 mm a 54mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a47'),
#   'descricao': 'Joelho 90° CPVC de +42 mm a 54mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a48'),
#   'descricao': 'Joelho 90° de Transição CPVC 22mm x 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a49'),
#   'descricao': 'Joelho 90° PPR até 20mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a4a'),
#   'descricao': 'Joelho 90° PVC Esgoto 150mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a4b'),
#   'descricao': 'Joelho 90° PVC Série R até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a4c'),
#   'descricao': 'Joelho 90° PVC Série R de +75mm até 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a4d'),
#   'descricao': 'Joelho 90° PVC Série R Esgoto até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a4e'),
#   'descricao': 'Joelho 90° PVC Soldável 32mm x 25mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a4f'),
#   'descricao': 'Joelho 90° PVC Soldável até 25mm x 3/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a50'),
#   'descricao': 'Joelho 90° PVC Soldável até 32mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a51'),
#   'descricao': 'Joelho 90° PVC Soldável de +32mm até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a52'),
#   'descricao': 'Joelho 90° PVC Soldável de +50mm até 60mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a53'),
#   'descricao': 'Junção 45° PVC de Redução Soldável Esgoto 75mm x 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a54'),
#   'descricao': 'Junção 45° PVC Roscável 1 1/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a55'),
#   'descricao': 'Junção 45° PVC Roscável 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a56'),
#   'descricao': 'Junção 45° PVC Série R 100mm x 75mm até 100mm x 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a57'),
#   'descricao': 'Junção 45° PVC Série R 75mm x 50mm até 75mm x 75mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a58'),
#   'descricao': 'Junção 45° PVC Série R Esgoto 100mm x 75mm até 100mm x 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a59'),
#   'descricao': 'Junção 45° PVC Série R Esgoto 75mm x 50mm até 75mm x 75mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a5a'),
#   'descricao': 'Junção 45° PVC Soldável 60mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a5b'),
#   'descricao': 'Kit Mecanismo Descarga para Caixa Acoplada',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a5c'),
#   'descricao': 'Kit Ralo Completo Universal para Bebedouro de Pressão',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a5d'),
#   'descricao': 'Kit Torneiras Válvulas Jato e Copo para Bebedouro de Pressão',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a5e'),
#   'descricao': 'Lata de Espuma Expansiva 500mL Quartzolit',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a5f'),
#   'descricao': 'Luva CPVC até 28mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a60'),
#   'descricao': 'Luva CPVC de +28mm até 42mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a61'),
#   'descricao': 'Luva CPVC de Transição até 22mm x 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a62'),
#   'descricao': 'Luva CPVC de Transição de +22mm x 1/2" até 28mm x 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a63'),
#   'descricao': 'Luva de Cobre até 28mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a64'),
#   'descricao': 'Luva de Cobre de +28mm até 42mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a65'),
#   'descricao': 'Luva de Cobre de +42mm até 54mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a66'),
#   'descricao': 'Luva de Correr Esgoto Série R até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a67'),
#   'descricao': 'Luva de Correr Série R Esgoto 200mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a68'),
#   'descricao': 'Luva de Correr Série R Esgoto até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a69'),
#   'descricao': 'Luva de Correr Série R Esgoto de +50mm até 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a6a'),
#   'descricao': 'Luva Galvanizado até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a6b'),
#   'descricao': 'Luva Galvanizado de Redução até 1" x 3/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a6c'),
#   'descricao': 'Luva Galvanizado de Redução de +1" x 3/4" até 2 1/2" x 2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a6d'),
#   'descricao': 'Luva para Eletroduto 2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a6e'),
#   'descricao': 'Luva para Eletroduto 3/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a6f'),
#   'descricao': 'Luva para Eletroduto até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a70'),
#   'descricao': 'Luva PPR até 32mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a71'),
#   'descricao': 'Luva PPR de +32mm até 40mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a72'),
#   'descricao': 'Luva PVC de Redução Esgoto até 100mm x 75mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a73'),
#   'descricao': 'Luva PVC de Redução Soldável Esgoto até 75mm x 60mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a74'),
#   'descricao': 'Luva PVC de Redução Soldável Esgoto de +75mm x 60mm até 110mm x 75mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a75'),
#   'descricao': 'Luva PVC Esgoto de +150mm até 200mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a76'),
#   'descricao': 'Luva PVC Esgoto Série R até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a77'),
#   'descricao': 'Luva PVC Esgoto Série R de +50mm até 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a78'),
#   'descricao': 'Luva PVC lr Soldável com Bucha de Latão até 25mm x 3/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a79'),
#   'descricao': 'Luva PVC lr Soldável com Bucha de Latão de +25mm x 3/4" até 32mm x 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a7a'),
#   'descricao': 'Luva PVC Roscável até 1 1/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a7b'),
#   'descricao': 'Luva PVC Série R Esgoto até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a7c'),
#   'descricao': 'Luva PVC Série R Esgoto de +50mm até 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a7d'),
#   'descricao': 'Luva pvc soldável até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a7e'),
#   'descricao': 'Luva PVC Soldável de +50mm até 75mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a7f'),
#   'descricao': 'Luva PVC Soldável de +75mm até 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a80'),
#   'descricao': 'Luva PVC Soldável de Correr até 32mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a81'),
#   'descricao': 'Luva PVC Soldável de Correr de +32mm até 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a82'),
#   'descricao': 'Mangueira Cristal 5/16"',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a83'),
#   'descricao': 'Mangueira para bebedouro de 1/4" a 3/8"',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a84'),
#   'descricao': 'Mecanismo Conversor Registro de Pressão MVS 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a85'),
#   'descricao': 'Módulo Cego Branco para espelho Dutotec',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a86'),
#   'descricao': 'Módulo Cego Branco para espelho Dutotec',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a87'),
#   'descricao': 'Niple Adaptador Conector IBBL Fr600',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a88'),
#   'descricao': 'Niple Ferro Galvanizado 2 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a89'),
#   'descricao': 'Niple Ferro Galvanizado até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a8a'),
#   'descricao': 'Niple PVC Roscável 2 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a8b'),
#   'descricao': 'Niple PVC Roscável 2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a8c'),
#   'descricao': 'Niple PVC Roscável até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a8d'),
#   'descricao': 'Organizador Espiral de 1/2" para Cabos',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a8e'),
#   'descricao': 'Pasta para Solda 110g',
#   'unidade': 'unid.',
#   'fabReferencia': 'VONDER',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a8f'),
#   'descricao': 'Pasta Térmica 100g',
#   'unidade': 'unid.',
#   'fabReferencia': 'IMPLASTEC',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a90'),
#   'descricao': 'Pasta Térmica 100g',
#   'unidade': 'unid.',
#   'fabReferencia': 'IMPLASTEC',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a91'),
#   'descricao': 'Perfil Canaleta F530 para Gesso Acartonado / Drywall - 3 Metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a92'),
#   'descricao': 'Placa Cega | 4x2 | 4x4 | Branca / Cinza',
#   'unidade': 'unid.',
#   'fabReferencia': 'TRAMONTINA',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a93'),
#   'descricao': 'Placa de Sinalização de Alta Tensão',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a94'),
#   'descricao': 'Plug de Sobrepor 2P+T Macho 10A',
#   'unidade': 'unid.',
#   'fabReferencia': 'Pial Legrand',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a95'),
#   'descricao': 'Plug de Sobrepor 2P+T Macho 20A',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a96'),
#   'descricao': 'Plug Roscável PVC até 1 1/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a97'),
#   'descricao': 'Plug Roscável PVC até 1 1/4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a98'),
#   'descricao': 'Porca Olhal 5/8"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a99'),
#   'descricao': 'Porca Olhal 5/8"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a9a'),
#   'descricao': 'Porca Sextavada 3/8"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a9b'),
#   'descricao': 'Porta Papel Higiênico Cromado Tampa Inox',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a9c'),
#   'descricao': 'Porta Toalha Banho em Metal Cromado tipo Barra',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a9d'),
#   'descricao': 'Ralo com Sifão Redondo 10cm x 10cm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a9e'),
#   'descricao': 'Ralo Grelha Abacaxi Ferro Fundido até 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8a9f'),
#   'descricao': 'Ralo Inox com Caixilho 15cm x 15cm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aa0'),
#   'descricao': 'Refil Maçarico Gás Mapp 400g',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aa1'),
#   'descricao': 'Rejunte 1Kg',
#   'unidade': 'kg',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aa2'),
#   'descricao': 'Reparo Original Hydra',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aa3'),
#   'descricao': 'Resistência de Aquecimento para Chuveiro 7500W 220V',
#   'unidade': 'unid.',
#   'fabReferencia': 'Lorenzetti',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aa4'),
#   'descricao': 'Rolamento Rígido de Esferas GBR 6308-ZZ',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aa5'),
#   'descricao': 'Roldana Ferro de 1 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aa6'),
#   'descricao': 'Rolo de Lã 10cm Pinta Faixa',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aa7'),
#   'descricao': 'Saco de Areia Lavada Grossa de 20Kg',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aa8'),
#   'descricao': 'Sensor Fim de Curso Reed Motor de Portão Rossi',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aa9'),
#   'descricao': 'Sifão de Ralo para Bebedouros BAG 40 IBBL',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aaa'),
#   'descricao': 'Sifão Sanfonado Multiuso Branco',
#   'unidade': 'unid.',
#   'fabReferencia': 'TIGRE',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aab'),
#   'descricao': 'Silicone 280g Acético Uso Geral',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aac'),
#   'descricao': 'Sinaleiro Redondo LED Verde 220V 22mm',
#   'unidade': 'unid.',
#   'fabReferencia': 'SCHNEIDER',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aad'),
#   'descricao': 'Soquete de Porcelana E27',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aae'),
#   'descricao': 'Soquete para Lâmpada Dicróica Gu10',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aaf'),
#   'descricao': 'Tampa Cega para Condulete até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': 'TRAMONTINA',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ab0'),
#   'descricao': 'Tampão para Condulete Múltiplo até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ab1'),
#   'descricao': 'Tê Cobre 22mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ab2'),
#   'descricao': 'Tê Cobre 28mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ab3'),
#   'descricao': 'Tê Cobre 42mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ab4'),
#   'descricao': 'Tê CPVC 54mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ab5'),
#   'descricao': 'Tê CPVC até 28mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ab6'),
#   'descricao': 'Tê CPVC de Redução 28mm x 22mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ab7'),
#   'descricao': 'Tê de Redução Galvanizado 2" x 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ab8'),
#   'descricao': 'Tê Galvanizado até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ab9'),
#   'descricao': 'Tê Galvanizado até 2 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aba'),
#   'descricao': 'Tê PPR 20mm x 20mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8abb'),
#   'descricao': 'Tê PPR 32mm x 25mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8abc'),
#   'descricao': 'Tê PPR 32mm x 25mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8abd'),
#   'descricao': 'Tê PVC Esgoto 100mm x 75mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8abe'),
#   'descricao': 'Tê PVC Esgoto 40mm x 40mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8abf'),
#   'descricao': 'Tê PVC Esgoto 50mm x 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ac0'),
#   'descricao': 'Tê PVC Esgoto 75mm x 75mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ac1'),
#   'descricao': 'Tê PVC Soldável 25mm x 25mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ac2'),
#   'descricao': 'Tê PVC Soldável 32mm x 32mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ac3'),
#   'descricao': 'Tê PVC Soldável 50mm x 25mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ac4'),
#   'descricao': 'Tê PVC Soldável 50mm x 32mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ac5'),
#   'descricao': 'Tê PVC Soldável 50mm x 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ac6'),
#   'descricao': 'Tê PVC Soldável 60mm x 60mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ac7'),
#   'descricao': 'Tê PVC Soldável 75mm x 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ac8'),
#   'descricao': 'Terminal Compressão para Cabos 6mm²',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ac9'),
#   'descricao': 'Terminal de Ventilação 100mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8aca'),
#   'descricao': 'Terminal Sapata para Cabos 16mm²',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8acb'),
#   'descricao': 'Torneira Bóia Caixa Bebedouro 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8acc'),
#   'descricao': 'Torneira para Bebedouro D32356',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8acd'),
#   'descricao': 'União CPVC Aquatherm até 28mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ace'),
#   'descricao': 'União Ferro Galvanizado 1" Assento Cônico em Bronze',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8acf'),
#   'descricao': 'União PVC Roscável até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ad0'),
#   'descricao': 'União PVC Soldável 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ad1'),
#   'descricao': 'União PVC Soldável 60mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ad2'),
#   'descricao': 'União PVC Soldável até 32mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ad3'),
#   'descricao': 'Veda Calha Cinza 310mL',
#   'unidade': 'unid.',
#   'fabReferencia': 'BAUTECH',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ad4'),
#   'descricao': 'Cartucho do Filtro da Bomba Mink',
#   'unidade': 'unid.',
#   'fabReferencia': 'EVAC',
#   'categoria': 'Fixo'},
#  {'_id': ObjectId('6070e3301c0178a7a57c8ad5'),
# ...
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b67'),
#   'descricao': 'Registro de Esfera 1 1/2" Docol',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b68'),
#   'descricao': 'Registro de Esfera 2" Docol',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b69'),
#   'descricao': 'Registro de Esfera 3/4" Deca',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b6a'),
#   'descricao': 'Registro de Esfera 3/4" Docol',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b6b'),
#   'descricao': 'Registro de Esfera 3/4" Docol',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b6c'),
#   'descricao': 'Registro de Esfera PVC 32mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b6d'),
#   'descricao': 'Registro de Esfera PVC 50mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b6e'),
#   'descricao': 'Registro de Esfera VS Roscável 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b6f'),
#   'descricao': "Registro de Pressão de 3/4'' com Acabamento C50",
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b70'),
#   'descricao': 'Régua 4 Tomadas 2P+T 10A',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b71'),
#   'descricao': 'Rejunte 1Kg',
#   'unidade': 'kg',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b72'),
#   'descricao': 'Rejunte 5Kg',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b73'),
#   'descricao': 'Relé Falta de Fase Trifásico 380V',
#   'unidade': 'unid.',
#   'fabReferencia': 'Coel',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b74'),
#   'descricao': 'Relé Fotoelétrico 220V',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b75'),
#   'descricao': 'Reservatório Evaporador Universal para Bebedouro de Pressão 40L',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b76'),
#   'descricao': 'Revestimento Impermeabilizante Viaplus 1000 Caixa 18Kg',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b77'),
#   'descricao': 'Revestimento Impermeabilizante Viaplus 5000 Caixa 18Kg',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b78'),
#   'descricao': 'Rodízio Giratório PU Injetado 6"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b79'),
#   'descricao': 'Rodízio Giratório PVC 4"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b7a'),
#   'descricao': 'Rodízio para Container 8"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b7b'),
#   'descricao': 'Rodízio para Container 8"',
#   'unidade': 'unid.',
#   'fabReferencia': 'Vonder/Novex',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b7c'),
#   'descricao': 'Rolamento Esfera de Contato Angular 3307 ATN9/C3 (porta giratoria)',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b7d'),
#   'descricao': 'Saco de Areia Lavada Fina de 25Kg',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b7e'),
#   'descricao': 'Saco de Areia Lavada Média de 25Kg',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b7f'),
#   'descricao': 'Saco de Brita 20Kg',
#   'unidade': 'unid.',
#   'fabReferencia': 'Ciplan',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b80'),
#   'descricao': 'Saco de Cimento de 50Kg',
#   'unidade': 'unid.',
#   'fabReferencia': 'Tocantins',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b81'),
#   'descricao': 'Selante Acrílico Flexível Sikacryl 459g',
#   'unidade': 'unid.',
#   'fabReferencia': 'SIKA',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b82'),
#   'descricao': 'Selante de Silicone',
#   'unidade': 'unid.',
#   'fabReferencia': 'SIKA',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b83'),
#   'descricao': 'Selo Mecânico 25MB ref: J038218900 ou equivalente',
#   'unidade': 'unid.',
#   'fabReferencia': 'JETS',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b84'),
#   'descricao': 'Sensor de Nível Condutivo ref.: D032316100',
#   'unidade': 'unid.',
#   'fabReferencia': 'JETS',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b85'),
#   'descricao': 'Sensor de Nível Full 250 - P/N: 2503078-001',
#   'unidade': 'unid.',
#   'fabReferencia': 'EVAC',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b86'),
#   'descricao': 'Sensor de Presença com Foto Célula.',
#   'unidade': 'unid.',
#   'fabReferencia': 'Decorlux',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b87'),
#   'descricao': 'Sifão Regulável para Mictório até 2" Cromado',
#   'unidade': 'unid.',
#   'fabReferencia': 'Esteves',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b88'),
#   'descricao': 'Silicone 280g Acético Uso Geral - Incolor / Bronze / Branco',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b89'),
#   'descricao': 'Silicone 280g Antifungo Antimofo',
#   'unidade': 'unid.',
#   'fabReferencia': 'TYTAN',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b8a'),
#   'descricao': 'Silicone 50g Alta Temperatura - Incolor / Vermelho',
#   'unidade': 'unid.',
#   'fabReferencia': 'ORBI',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b8b'),
#   'descricao': 'Sinaleiro Redondo LED Amarelo 220V 22mm',
#   'unidade': 'unid.',
#   'fabReferencia': 'SCHNEIDER',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b8c'),
#   'descricao': 'Soft Starter WEG 25cv / 380V',
#   'unidade': 'unid.',
#   'fabReferencia': 'WEG',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b8d'),
#   'descricao': 'Soquete Pressão para Lâmpada Fluorescente',
#   'unidade': 'unid.',
#   'fabReferencia': 'Decorlux',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b8e'),
#   'descricao': 'Soquete Rabicho para Lâmpada',
#   'unidade': 'unid.',
#   'fabReferencia': 'Decorlux',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b8f'),
#   'descricao': 'Suporte do Flap de Borracha ref: J023280091 ou equivalente',
#   'unidade': 'unid.',
#   'fabReferencia': 'JETS',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b90'),
#   'descricao': 'Termostato com Regulador para Bebedouro RC 42600-2',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b91'),
#   'descricao': 'Tinta Acrílica para Pisos',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b92'),
#   'descricao': 'Tinta Acrílica Semibrilho',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b93'),
#   'descricao': 'Tinta em Pó Xadrez 250g Vermelha',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b94'),
#   'descricao': 'Torneira Automática Docol Pressmatic',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b95'),
#   'descricao': 'Torneira Cromada Alta para Bebedouro',
#   'unidade': 'unid.',
#   'fabReferencia': 'Here',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b96'),
#   'descricao': 'Torneira Cromada Baixa para Bebedouro',
#   'unidade': 'unid.',
#   'fabReferencia': 'Here',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b97'),
#   'descricao': 'Torneira Cromada para Pia de Banheiro',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b98'),
#   'descricao': 'Torneira Esfera 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b99'),
#   'descricao': 'Tubo Cobre 22mm Classe "i"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b9a'),
#   'descricao': 'Tubo Cobre 28mm Classe "i"',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b9b'),
#   'descricao': 'Tubo Cobre 35mm Classe "i"',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b9c'),
#   'descricao': 'Tubo Cobre 42mm Classe "i"',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b9d'),
#   'descricao': 'Tubo Cobre 54mm Classe "i"',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b9e'),
#   'descricao': 'Tubo CPVC 54mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8b9f'),
#   'descricao': 'Tubo CPVC até 22mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8ba0'),
#   'descricao': 'Tubo CPVC de +22mm até 28mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8ba1'),
#   'descricao': 'Tubo CPVC de +35mm a 42mm',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8ba2'),
#   'descricao': 'Tubo Galvanizado 2 e 1/2"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8ba3'),
#   'descricao': 'Tubo Galvanizado até 1"',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8ba4'),
#   'descricao': 'Tubo PPR 32mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8ba5'),
#   'descricao': 'Tubo PPR 40mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8ba6'),
#   'descricao': 'Tubo PPR até 25mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8ba7'),
#   'descricao': 'Tubo PVC Esgoto 100mm - Barra 6 metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8ba8'),
#   'descricao': 'Tubo PVC Esgoto 150mm - Barra 6 metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8ba9'),
#   'descricao': 'Tubo PVC Esgoto 200mm - Barra 6 metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8baa'),
#   'descricao': 'Tubo PVC Esgoto 40mm - Barra 6 metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bab'),
#   'descricao': 'Tubo PVC Esgoto 50mm - Barra 6 metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bac'),
#   'descricao': 'Tubo PVC Esgoto 75mm - Barra 6 metros',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bad'),
#   'descricao': 'Tubo PVC para Eletroduto 3/4"',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bae'),
#   'descricao': 'Tubo PVC Série R até 75mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8baf'),
#   'descricao': 'Tubo PVC Série R de +75mm até 100mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bb0'),
#   'descricao': 'Tubo PVC Série R Esgoto 100mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bb1'),
#   'descricao': 'Tubo PVC Série R Esgoto até 75mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bb2'),
#   'descricao': 'Tubo PVC Soldável 60mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bb3'),
#   'descricao': 'Tubo PVC Soldável até 25mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bb4'),
#   'descricao': 'Tubo PVC Soldável de +25mm até 50mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bb5'),
#   'descricao': 'Tubo PVC Soldável de 60mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bb6'),
#   'descricao': 'Tubo PVC Soldável de 75mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bb7'),
#   'descricao': 'Tubo PVC Soldável Esgoto de +25mm até 50mm',
#   'unidade': 'm',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bb8'),
#   'descricao': 'Válvula de Descarga Deca Hydra Max Clean Pro',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bb9'),
#   'descricao': 'Válvula ED-Valve 220V interface ref.: J052508002',
#   'unidade': 'unid.',
#   'fabReferencia': 'JETS',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bba'),
#   'descricao': 'Válvula para Mictório Decalux Acionamento Automático 220V',
#   'unidade': 'unid.',
#   'fabReferencia': 'Deca',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bbb'),
#   'descricao': 'Válvula Solenóide 12V de Entrada de Água para Torneira',
#   'unidade': 'unid.',
#   'fabReferencia': '-',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bbc'),
#   'descricao': 'Vidro Temperado Bronze de Espessura 10mm - Instalado',
#   'unidade': 'm²',
#   'fabReferencia': 'Vidraçaria Brasília',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bbd'),
#   'descricao': 'Vidro Temperado Incolor de Espessura 10mm - Instalado',
#   'unidade': 'm²',
#   'fabReferencia': 'Vidraçaria Brasília',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bbe'),
#   'descricao': 'Kit de reparo bomba mink',
#   'unidade': 'unid.',
#   'fabReferencia': 'EVAC',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bbf'),
#   'descricao': 'Oléo sintético (1l) - P/N: B111259',
#   'unidade': 'unid.',
#   'fabReferencia': 'EVAC',
#   'categoria': 'Sob Demanda'},
#  {'_id': ObjectId('6070e3481c0178a7a57c8bc0'),
#   'descricao': 'Parafuso s/ cabeca 6x25',
#   'unidade': 'unid.',
#   'fabReferencia': 'JETS',
#   'categoria': 'Sob Demanda'}]

# %%
fixos = pd.read_csv("../Fixos.csv", sep=";", encoding='latin') \
.drop(["N°", "Valor Anual "], axis=1) \
.rename({"Descrição ": "descricao", 
         "Unid.": "unidade", 
         "Quantidade Anual ": "quantidadeAnual", 
         "Fabricante Referência": "fabReferencia",
         "Valor Unitário (R$)": "valorUnitario"}, axis=1)

fixos['valorUnitario'] = fixos['valorUnitario'].apply(lambda x: float(x.replace(',', '.')))

fixos['unidade'] = fixos['unidade'].map({"Und.": "unid.", "metro": "m", "Kg": "kg"})
fixos['categoria'] = "Fixo"

fixos
# Out:
#                                              descricao unidade  valorUnitario  \
# 0                       Abraçadeira de Nylon até 200mm   unid.           0.03
# 1               Abraçadeira de Nylon de +200mm a 390mm   unid.           0.47
# 2               Abraçadeira de Nylon de +390mm a 535mm   unid.           0.69
# 3            Abraçadeira em Aço tipo Copo até 1 e 1/2"   unid.           0.61
# 4               Abraçadeira em Aço tipo D até 1 e 1/2"   unid.           1.94
# ..                                                 ...     ...            ...
# 281  Kit (5 camadas de cristal de quartzo e 1 camad...   unid.          93.75
# 282                              Refil Filtro IBBL c+3   unid.          24.95
# 283                               Refil Pré Filtro C+3   unid.          35.90
# 284                              Refil de Filtro PB603   unid.           9.11
# 285                     Refil de Filtro Polifil EF 200   unid.          11.00
#
#          fabReferencia  quantidadeAnual categoria
# 0            Hellerman              432      Fixo
# 1            Hellerman              208      Fixo
# 2            Hellerman               73      Fixo
# 3                    -               67      Fixo
# 4                    -               38      Fixo
# ..                 ...              ...       ...
# 281           Filtrale                8      Fixo
# 282                  -               18      Fixo
# 283                  -               18      Fixo
# 284                  -              258      Fixo
# 285  Mundo dos filtros               60      Fixo
#
# [286 rows x 6 columns]

# %%
fixos['unidade'].value_counts()
# Out:
# unid.    279
# m          5
# kg         2
# Name: unidade, dtype: int64

# %%
dicts = []
for index, row in fixos.iterrows():
    curr = {}
    for col in row.index:
        curr[col] = row[col]
        
    dicts.append(curr)
    
dicts

# %%
pedidos_ids = postMany(dicts)
pedidos_ids
# Out:
# [ObjectId('60779202707a8271c5332528'),
#  ObjectId('60779202707a8271c5332529'),
#  ObjectId('60779202707a8271c533252a'),
#  ObjectId('60779202707a8271c533252b'),
#  ObjectId('60779202707a8271c533252c'),
#  ObjectId('60779202707a8271c533252d'),
#  ObjectId('60779202707a8271c533252e'),
#  ObjectId('60779202707a8271c533252f'),
#  ObjectId('60779202707a8271c5332530'),
#  ObjectId('60779202707a8271c5332531'),
#  ObjectId('60779202707a8271c5332532'),
#  ObjectId('60779202707a8271c5332533'),
#  ObjectId('60779202707a8271c5332534'),
#  ObjectId('60779202707a8271c5332535'),
#  ObjectId('60779202707a8271c5332536'),
#  ObjectId('60779202707a8271c5332537'),
#  ObjectId('60779202707a8271c5332538'),
#  ObjectId('60779202707a8271c5332539'),
#  ObjectId('60779202707a8271c533253a'),
#  ObjectId('60779202707a8271c533253b'),
#  ObjectId('60779202707a8271c533253c'),
#  ObjectId('60779202707a8271c533253d'),
#  ObjectId('60779202707a8271c533253e'),
#  ObjectId('60779202707a8271c533253f'),
#  ObjectId('60779202707a8271c5332540'),
#  ObjectId('60779202707a8271c5332541'),
#  ObjectId('60779202707a8271c5332542'),
#  ObjectId('60779202707a8271c5332543'),
#  ObjectId('60779202707a8271c5332544'),
#  ObjectId('60779202707a8271c5332545'),
#  ObjectId('60779202707a8271c5332546'),
#  ObjectId('60779202707a8271c5332547'),
#  ObjectId('60779202707a8271c5332548'),
#  ObjectId('60779202707a8271c5332549'),
#  ObjectId('60779202707a8271c533254a'),
#  ObjectId('60779202707a8271c533254b'),
#  ObjectId('60779202707a8271c533254c'),
#  ObjectId('60779202707a8271c533254d'),
#  ObjectId('60779202707a8271c533254e'),
#  ObjectId('60779202707a8271c533254f'),
#  ObjectId('60779202707a8271c5332550'),
#  ObjectId('60779202707a8271c5332551'),
#  ObjectId('60779202707a8271c5332552'),
#  ObjectId('60779202707a8271c5332553'),
#  ObjectId('60779202707a8271c5332554'),
#  ObjectId('60779202707a8271c5332555'),
#  ObjectId('60779202707a8271c5332556'),
#  ObjectId('60779202707a8271c5332557'),
#  ObjectId('60779202707a8271c5332558'),
#  ObjectId('60779202707a8271c5332559'),
#  ObjectId('60779202707a8271c533255a'),
#  ObjectId('60779202707a8271c533255b'),
#  ObjectId('60779202707a8271c533262d'),
#  ObjectId('60779202707a8271c533262e'),
#  ObjectId('60779202707a8271c533262f'),
#  ObjectId('60779202707a8271c5332630'),
#  ObjectId('60779202707a8271c5332631'),
#  ObjectId('60779202707a8271c5332632'),
#  ObjectId('60779202707a8271c5332633'),
#  ObjectId('60779202707a8271c5332634'),
#  ObjectId('60779202707a8271c5332635'),
#  ObjectId('60779202707a8271c5332636'),
#  ObjectId('60779202707a8271c5332637'),
#  ObjectId('60779202707a8271c5332638'),
#  ObjectId('60779202707a8271c5332639'),
#  ObjectId('60779202707a8271c533263a'),
#  ObjectId('60779202707a8271c533263b'),
#  ObjectId('60779202707a8271c533263c'),
#  ObjectId('60779202707a8271c533263d'),
#  ObjectId('60779202707a8271c533263e'),
#  ObjectId('60779202707a8271c533263f'),
#  ObjectId('60779202707a8271c5332640'),
#  ObjectId('60779202707a8271c5332641'),
#  ObjectId('60779202707a8271c5332642'),
#  ObjectId('60779202707a8271c5332643'),
#  ObjectId('60779202707a8271c5332644'),
#  ObjectId('60779202707a8271c5332645')]

# %%
sobdemanda = pd.read_csv("../SobDemanda.csv", sep=";", encoding='latin') \
.drop(["N°", "Valor Anual Revisado"], axis=1) \
.rename({"Descrição Revisada": 
         "descricao", 
         "Unid.": "unidade", 
         "Fabricante Referência": "fabReferencia",
         "Valor Unitário (R$)": "valorUnitario",
         "Quantidade Anual Revisada": "quantidadeAnual"}, axis=1)

sobdemanda['unidade'] = sobdemanda['unidade'].map({"Und.": "unid.", "metro": "m", "Kg": "kg", "m²": "m²"})
sobdemanda['descricao'] = sobdemanda['descricao'].apply(lambda x: x.strip())

sobdemanda['valorUnitario'] = sobdemanda['valorUnitario'].apply(lambda x: float(x.replace('.', '').replace(',', '.')))

sobdemanda['categoria'] = "Sob Demanda"

sobdemanda
# Out:
#                                              descricao unidade  valorUnitario  \
# 0                  Acabamento para válvula de descarga   unid.         126.92
# 1              Adesivo para Piso Vinílico Acrílico 5Kg   unid.          55.30
# 2                    Anel de Vedação O-ring para Bomba   unid.           0.49
# 3                        Aquecedor Elétrico 220v/5500w   unid.          88.20
# 4                             Argamassa AC3 Cinza 20Kg   unid.          31.43
# ..                                                 ...     ...            ...
# 226  Vidro Temperado Bronze de Espessura 10mm - Ins...      m²         204.62
# 227  Vidro Temperado Incolor de Espessura 10mm - In...      m²          76.74
# 228                           Kit de reparo bomba mink   unid.        5600.12
# 229                 Oléo sintético (1l) - P/N: B111259   unid.         488.60
# 230                            Parafuso s/ cabeca 6x25   unid.          29.43
#
#            fabReferencia  quantidadeAnual    categoria
# 0                   Deca                2  Sob Demanda
# 1                      -                1  Sob Demanda
# 2                      -                2  Sob Demanda
# 3                      -                2  Sob Demanda
# 4              Votomassa                5  Sob Demanda
# ..                   ...              ...          ...
# 226  Vidraçaria Brasília               10  Sob Demanda
# 227  Vidraçaria Brasília                5  Sob Demanda
# 228                 EVAC                1  Sob Demanda
# 229                 EVAC                8  Sob Demanda
# 230                 JETS               15  Sob Demanda
#
# [231 rows x 6 columns]

# %%
sobdemanda['unidade'].value_counts()
# Out:
# unid.    190
# m         37
# kg         2
# m²         2
# Name: unidade, dtype: int64

# %%
dicts = []
for index, row in sobdemanda.iterrows():
    curr = {}
    for col in row.index:
        curr[col] = row[col]
        
    dicts.append(curr)
    
dicts

# %%
pedido_id = postMany(dicts)
pedido_id
# Out:
# [ObjectId('607795cb707a8271c5332646'),
#  ObjectId('607795cb707a8271c5332647'),
#  ObjectId('607795cb707a8271c5332648'),
#  ObjectId('607795cb707a8271c5332649'),
#  ObjectId('607795cb707a8271c533264a'),
#  ObjectId('607795cb707a8271c533264b'),
#  ObjectId('607795cb707a8271c533264c'),
#  ObjectId('607795cb707a8271c533264d'),
#  ObjectId('607795cb707a8271c533264e'),
#  ObjectId('607795cb707a8271c533264f'),
#  ObjectId('607795cb707a8271c5332650'),
#  ObjectId('607795cb707a8271c5332651'),
#  ObjectId('607795cb707a8271c5332652'),
#  ObjectId('607795cb707a8271c5332653'),
#  ObjectId('607795cb707a8271c5332654'),
#  ObjectId('607795cb707a8271c5332655'),
#  ObjectId('607795cb707a8271c5332656'),
#  ObjectId('607795cb707a8271c5332657'),
#  ObjectId('607795cb707a8271c5332658'),
#  ObjectId('607795cb707a8271c5332659'),
#  ObjectId('607795cb707a8271c533265a'),
#  ObjectId('607795cb707a8271c533265b'),
#  ObjectId('607795cb707a8271c533265c'),
#  ObjectId('607795cb707a8271c533265d'),
#  ObjectId('607795cb707a8271c533265e'),
#  ObjectId('607795cb707a8271c533265f'),
#  ObjectId('607795cb707a8271c5332660'),
#  ObjectId('607795cb707a8271c5332661'),
#  ObjectId('607795cb707a8271c5332662'),
#  ObjectId('607795cb707a8271c5332663'),
#  ObjectId('607795cb707a8271c5332664'),
#  ObjectId('607795cb707a8271c5332665'),
#  ObjectId('607795cb707a8271c5332666'),
#  ObjectId('607795cb707a8271c5332667'),
#  ObjectId('607795cb707a8271c5332668'),
#  ObjectId('607795cb707a8271c5332669'),
#  ObjectId('607795cb707a8271c533266a'),
#  ObjectId('607795cb707a8271c533266b'),
#  ObjectId('607795cb707a8271c533266c'),
#  ObjectId('607795cb707a8271c533266d'),
#  ObjectId('607795cb707a8271c533266e'),
#  ObjectId('607795cb707a8271c533266f'),
#  ObjectId('607795cb707a8271c5332670'),
#  ObjectId('607795cb707a8271c5332671'),
#  ObjectId('607795cb707a8271c5332672'),
#  ObjectId('607795cb707a8271c5332673'),
#  ObjectId('607795cb707a8271c5332674'),
#  ObjectId('607795cb707a8271c5332675'),
#  ObjectId('607795cb707a8271c5332676'),
#  ObjectId('607795cb707a8271c5332677'),
#  ObjectId('607795cb707a8271c5332678'),
#  ObjectId('607795cb707a8271c5332679'),
#  ObjectId('607795cb707a8271c533267a'),
#  ObjectId('607795cb707a8271c533267b'),
#  ObjectId('607795cb707a8271c533267c'),
#  ObjectId('607795cb707a8271c533267d'),
#  ObjectId('607795cb707a8271c533267e'),
#  ObjectId('607795cb707a8271c533267f'),
#  ObjectId('607795cb707a8271c5332680'),
#  ObjectId('607795cb707a8271c5332681'),
#  ObjectId('607795cb707a8271c5332682'),
#  ObjectId('607795cb707a8271c5332683'),
#  ObjectId('607795cb707a8271c5332708'),
#  ObjectId('607795cb707a8271c5332709'),
#  ObjectId('607795cb707a8271c533270a'),
#  ObjectId('607795cb707a8271c533270b'),
#  ObjectId('607795cb707a8271c533270c'),
#  ObjectId('607795cb707a8271c533270d'),
#  ObjectId('607795cb707a8271c533270e'),
#  ObjectId('607795cb707a8271c533270f'),
#  ObjectId('607795cb707a8271c5332710'),
#  ObjectId('607795cb707a8271c5332711'),
#  ObjectId('607795cb707a8271c5332712'),
#  ObjectId('607795cb707a8271c5332713'),
#  ObjectId('607795cb707a8271c5332714'),
#  ObjectId('607795cb707a8271c5332715'),
#  ObjectId('607795cb707a8271c5332716'),
#  ObjectId('607795cb707a8271c5332717'),
#  ObjectId('607795cb707a8271c5332718'),
#  ObjectId('607795cb707a8271c5332719'),
#  ObjectId('607795cb707a8271c533271a'),
#  ObjectId('607795cb707a8271c533271b'),
#  ObjectId('607795cb707a8271c533271c'),
#  ObjectId('607795cb707a8271c533271d'),
#  ObjectId('607795cb707a8271c533271e'),
#  ObjectId('607795cb707a8271c533271f'),
#  ObjectId('607795cb707a8271c5332720'),
#  ObjectId('607795cb707a8271c5332721'),
#  ObjectId('607795cb707a8271c5332722'),
#  ObjectId('607795cb707a8271c5332723'),
#  ObjectId('607795cb707a8271c5332724'),
#  ObjectId('607795cb707a8271c5332725'),
#  ObjectId('607795cb707a8271c5332726'),
#  ObjectId('607795cb707a8271c5332727'),
#  ObjectId('607795cb707a8271c5332728'),
#  ObjectId('607795cb707a8271c5332729'),
#  ObjectId('607795cb707a8271c533272a'),
#  ObjectId('607795cb707a8271c533272b'),
#  ObjectId('607795cb707a8271c533272c')]

# %% [markdown]
# ---

# %%
COLLECTION = "pedidosdecompra"
collection = db[COLLECTION]

# %%
all_data = getPedidos()
all_data
# Out:
# [{'_id': ObjectId('60779814e71a390cfa2f852a'),
#   'requisitante': 'Christian Cruvinel França',
#   'email': 'christian.franca@bcb.gov.br',
#   'os': '51332',
#   'items': [{'nome': 'Abraçadeira de Nylon até 200mm',
#     'descricao': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse.',
#     'quantidade': '2',
#     'categoria': 'Fixo',
#     'unidade': 'unid.',
#     'finalidade': 'Fixação de cabos',
#     'aprovadoAssistente': True,
#     'motivoAssistente': None,
#     'aprovadoFiscal': True,
#     'motivoFiscal': None,
#     'direcionamentoDeCompra': 'Engemil',
#     'almoxarifadoPossui': True},
#    {'nome': 'Canaleta PVC com Divisória 20x10 - 2 Metros',
#     'descricao': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse.',
#     'quantidade': '2',
#     'categoria': 'Fixo',
#     'unidade': 'unid.',
#     'finalidade': 'Ajuste de itens',
#     'aprovadoAssistente': True,
#     'motivoAssistente': None,
#     'aprovadoFiscal': True,
#     'motivoFiscal': None,
#     'direcionamentoDeCompra': 'Demap',
#     'almoxarifadoPossui': False},
#    {'nome': 'Fita de Demarcação Amarela 8mm',
#     'descricao': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse.',
#     'quantidade': '10',
#     'categoria': 'Fixo',
#     'unidade': 'm',
#     'finalidade': 'Manutenção de coisas',
#     'aprovadoAssistente': True,
#     'motivoAssistente': None,
#     'aprovadoFiscal': True,
#     'motivoFiscal': None,
#     'direcionamentoDeCompra': 'Engemil',
#     'almoxarifadoPossui': True}],
#   'dataPedido': '14/04/2021',
#   'dataCancelamento': None,
#   'dataFinalizacao': '14/04/2021',
#   'quantidade': 3,
#   'status': 'Solicitação finalizada',
#   'statusStep': 6,
#   'color': 'success',
#   'active': True},
#  {'_id': ObjectId('60779893e71a390cfa2f852b'),
#   'requisitante': 'Vitor Miranda Kurovski',
#   'email': 'kurovski@bcb.gov.br',
#   'os': '12141',
#   'items': [{'nome': 'Lâmpada Fluorescente 26W Base E-27 (Amarela)',
#     'descricao': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse.',
#     'quantidade': '1',
#     'categoria': 'Sob Demanda',
#     'unidade': 'unid.',
#     'finalidade': 'Teste de gerador',
#     'aprovadoAssistente': False,
#     'motivoAssistente': 'Não é necessário',
#     'aprovadoFiscal': True,
#     'motivoFiscal': None,
#     'direcionamentoDeCompra': 'Engemil',
#     'almoxarifadoPossui': False},
#    {'nome': 'Reator para Lâmpada Vapor de Sódio 250W',
#     'descricao': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse.',
#     'quantidade': '3',
#     'categoria': 'Sob Demanda',
#     'unidade': 'unid.',
#     'finalidade': 'Lançamento de Disco',
#     'aprovadoAssistente': True,
#     'motivoAssistente': None,
#     'aprovadoFiscal': True,
#     'motivoFiscal': None,
#     'direcionamentoDeCompra': 'Engemil',
#     'almoxarifadoPossui': False}],
#   'dataPedido': '14/04/2021',
#   'dataCancelamento': None,
#   'dataFinalizacao': '14/04/2021',
#   'quantidade': 2,
#   'status': 'Solicitação finalizada',
#   'statusStep': 6,
#   'color': 'success',
#   'active': True},
#  {'_id': ObjectId('607798f8e71a390cfa2f852c'),
#   'requisitante': 'Charles Costa Ribeiro',
#   'email': 'charles.ribeiro@bcb.gov.br',
#   'os': '12304',
#   'items': [{'nome': 'Registro de Esfera PVC 50mm',
#     'descricao': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse.',
#     'quantidade': '2',
#     'categoria': 'Sob Demanda',
#     'unidade': 'unid.',
#     'finalidade': 'Ajuste de encanamento',
#     'aprovadoAssistente': True,
#     'motivoAssistente': None,
#     'aprovadoFiscal': True,
#     'motivoFiscal': None,
#     'direcionamentoDeCompra': 'Demap',
#     'almoxarifadoPossui': True},
#    {'nome': 'Cabo PP Flexível 3 x 2,5mm² Classe Encordoamento 5 0,6/1kV (Certificação Inmetro)',
#     'descricao': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.',
#     'quantidade': '100',
#     'categoria': 'Sob Demanda',
#     'unidade': 'm',
#     'finalidade': 'Montagem de nova rede elétrica',
#     'aprovadoAssistente': True,
#     'motivoAssistente': None,
#     'aprovadoFiscal': True,
#     'motivoFiscal': None,
#     'direcionamentoDeCompra': 'Demap',
#     'almoxarifadoPossui': True},
#    {'nome': 'Silicone 280g Antifungo Antimofo',
#     'descricao': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.',
#     'quantidade': '3',
#     'categoria': 'Sob Demanda',
#     'unidade': 'unid.',
#     'finalidade': 'Selagem de tanque',
#     'aprovadoAssistente': True,
#     'motivoAssistente': None,
#     'aprovadoFiscal': False,
#     'motivoFiscal': 'Silicone não é necessário agora',
#     'direcionamentoDeCompra': None,
#     'almoxarifadoPossui': True},
#    {'nome': 'Luva para Eletroduto 2"',
#     'descricao': 'Lorem ipsum dolor sit amet.',
#     'quantidade': '5',
#     'categoria': 'Fixo',
#     'unidade': 'unid.',
#     'finalidade': 'Conexão de eletroduto',
#     'aprovadoAssistente': True,
#     'motivoAssistente': None,
#     'aprovadoFiscal': False,
#     'motivoFiscal': 'Item fixo não se compra',
#     'direcionamentoDeCompra': None,
#     'almoxarifadoPossui': True}],
#   'dataPedido': '14/04/2021',
#   'dataCancelamento': None,
#   'dataFinalizacao': '14/04/2021',
#   'quantidade': 4,
#   'status': 'Solicitação finalizada',
#   'statusStep': 6,
#   'color': 'success',
#   'active': True},
#  {'_id': ObjectId('60779935e71a390cfa2f852d'),
#   'requisitante': 'Agenor Roney',
#   'email': 'roney.pereira@bcb.gov.br',
#   'os': '10032',
#   'items': [{'nome': 'Chave de roda aro 14"',
#     'descricao': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit.',
#     'quantidade': '10',
#     'categoria': 'Outro',
#     'unidade': 'unid.',
#     'finalidade': 'Arrumar meu fusca quebrado',
#     'aprovadoAssistente': True,
#     'motivoAssistente': None,
#     'aprovadoFiscal': False,
#     'motivoFiscal': 'Tá de zoeira, roney?',
#     'direcionamentoDeCompra': None,
#     'almoxarifadoPossui': True}],
#   'dataPedido': '14/04/2021',
#   'dataCancelamento': '14/04/2021',
#   'dataFinalizacao': None,
#   'quantidade': 1,
#   'status': 'Solicitação cancelada pelo(a) fiscal',
#   'statusStep': 3,
#   'color': 'red',
#   'active': False}]

# %%
df = pd.DataFrame.from_records(all_data)

# %%
df = pd.DataFrame.from_records(all_data)

def getCorrectDF(df):
    new_df = pd.DataFrame(columns=df.drop('items', axis=1).rename({'quantidade': 'quantidadeDeItens'}, axis=1).columns.tolist() + 
                          ['item_id'] +
                          list(df['items'][0][0].keys())) # Dataframe vazio

    j = 0
    for i, row in df.iterrows():
        item_id = 0
        cols_from_original = df.iloc[i].drop('items').rename({'quantidade': 'quantidadeDeItens'}, axis=1).to_dict() # Tendo a base de repetição
        cols_from_original['_id'] = str(cols_from_original['_id']) # Transforma aquele _id pro formato string
        for item in row['items']: # item é um dict
            cols_from_original.update(item) # Atualizamos todas as colunas do original com as novas colunas do item
            item = pd.Series(cols_from_original)
            item['item_id'] = item_id 

            new_df.loc[j] = item

            j += 1
            item_id += 1

    int_cols = ['statusStep', 'item_id', 'quantidadeDeItens']
    bool_cols = ['active', 'aprovadoAssistente', 'aprovadoFiscal', 'almoxarifadoPossui']
    float_cols = ['quantidade']

    new_df[int_cols] = new_df[int_cols].astype('int64')
    new_df[bool_cols] = new_df[bool_cols].astype('boolean')
    new_df[float_cols] = new_df[float_cols].astype('float')

    return new_df

df = getCorrectDF(df)
df
# Out:
#                         _id               requisitante  \
# 0  60779814e71a390cfa2f852a  Christian Cruvinel França
# 1  60779814e71a390cfa2f852a  Christian Cruvinel França
# 2  60779814e71a390cfa2f852a  Christian Cruvinel França
# 3  60779893e71a390cfa2f852b     Vitor Miranda Kurovski
# 4  60779893e71a390cfa2f852b     Vitor Miranda Kurovski
# 5  607798f8e71a390cfa2f852c      Charles Costa Ribeiro
# 6  607798f8e71a390cfa2f852c      Charles Costa Ribeiro
# 7  607798f8e71a390cfa2f852c      Charles Costa Ribeiro
# 8  607798f8e71a390cfa2f852c      Charles Costa Ribeiro
# 9  60779935e71a390cfa2f852d               Agenor Roney
#
#                          email     os  dataPedido dataCancelamento  \
# 0  christian.franca@bcb.gov.br  51332  14/04/2021             None
# 1  christian.franca@bcb.gov.br  51332  14/04/2021             None
# 2  christian.franca@bcb.gov.br  51332  14/04/2021             None
# 3          kurovski@bcb.gov.br  12141  14/04/2021             None
# 4          kurovski@bcb.gov.br  12141  14/04/2021             None
# 5   charles.ribeiro@bcb.gov.br  12304  14/04/2021             None
# 6   charles.ribeiro@bcb.gov.br  12304  14/04/2021             None
# 7   charles.ribeiro@bcb.gov.br  12304  14/04/2021             None
# 8   charles.ribeiro@bcb.gov.br  12304  14/04/2021             None
# 9     roney.pereira@bcb.gov.br  10032  14/04/2021       14/04/2021
#
#   dataFinalizacao  quantidadeDeItens                                status  \
# 0      14/04/2021                  3                Solicitação finalizada
# 1      14/04/2021                  3                Solicitação finalizada
# 2      14/04/2021                  3                Solicitação finalizada
# 3      14/04/2021                  2                Solicitação finalizada
# 4      14/04/2021                  2                Solicitação finalizada
# 5      14/04/2021                  4                Solicitação finalizada
# 6      14/04/2021                  4                Solicitação finalizada
# 7      14/04/2021                  4                Solicitação finalizada
# 8      14/04/2021                  4                Solicitação finalizada
# 9            None                  1  Solicitação cancelada pelo(a) fiscal
#
#    statusStep  ... quantidade    categoria  unidade  \
# 0           6  ...        2.0         Fixo    unid.
# 1           6  ...        2.0         Fixo    unid.
# 2           6  ...       10.0         Fixo        m
# 3           6  ...        1.0  Sob Demanda    unid.
# 4           6  ...        3.0  Sob Demanda    unid.
# 5           6  ...        2.0  Sob Demanda    unid.
# 6           6  ...      100.0  Sob Demanda        m
# 7           6  ...        3.0  Sob Demanda    unid.
# 8           6  ...        5.0         Fixo    unid.
# 9           3  ...       10.0        Outro    unid.
#
#                        finalidade aprovadoAssistente  motivoAssistente  \
# 0                Fixação de cabos               True              None
# 1                 Ajuste de itens               True              None
# 2            Manutenção de coisas               True              None
# 3                Teste de gerador              False  Não é necessário
# 4             Lançamento de Disco               True              None
# 5           Ajuste de encanamento               True              None
# 6  Montagem de nova rede elétrica               True              None
# 7               Selagem de tanque               True              None
# 8           Conexão de eletroduto               True              None
# 9      Arrumar meu fusca quebrado               True              None
#
#   aprovadoFiscal                     motivoFiscal direcionamentoDeCompra  \
# 0           True                             None                Engemil
# 1           True                             None                  Demap
# 2           True                             None                Engemil
# 3           True                             None                Engemil
# 4           True                             None                Engemil
# 5           True                             None                  Demap
# 6           True                             None                  Demap
# 7          False  Silicone não é necessário agora                   None
# 8          False          Item fixo não se compra                   None
# 9          False             Tá de zoeira, roney?                   None
#
#    almoxarifadoPossui
# 0                True
# 1               False
# 2                True
# 3               False
# 4               False
# 5                True
# 6                True
# 7                True
# 8                True
# 9                True
#
# [10 rows x 25 columns]

# %%
from io import StringIO

# %%
StringIO('alou.csv')
